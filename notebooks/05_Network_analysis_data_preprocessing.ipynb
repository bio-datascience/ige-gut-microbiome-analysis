# %%
import os
import sys

os.chdir('/container/mount/point/')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

import pickle as pkl

from tqdm import tqdm
from sklearn import preprocessing
from scipy.cluster.hierarchy import linkage, leaves_list

from gglasso.problem import glasso_problem
from gglasso.helper.basic_linalg import adjacency_matrix
from gglasso.helper.basic_linalg import scale_array_by_diagonal

from utils.helper import transform_features, scale_array_by_diagonal
from utils.preprocessing import add_noise_to_data

# %%
asv = pd.read_csv("data/feature_table.tsv", index_col=0, sep='\t')
control_sample_df = pd.read_csv("data/control_samples.csv", sep=",", index_col=0, low_memory=False)
cluster_df = pd.read_csv("data/cluster_df_latent.csv", sep=",", index_col =0, low_memory=False)
covariates = pd.read_csv("data/54subset_latent.csv", sep=",", index_col='u3_16s_id', low_memory=False)

asv_ige_508_filtered = pd.read_csv("data/asv_ige_508.csv", sep=",", index_col=0, low_memory=False)
co_occurrence_matrix = pd.read_csv("data/co_occurrence_matrix.csv", sep=",", index_col=0, low_memory=False)
taxa = pd.read_csv('data/taxonomy_clean.csv', sep=',', index_col=0)
taxa["ASV"] = taxa.index

# Subset the ASV data to include only columns 508 IgE samples
asv_ige_508_all = asv[asv_ige_508_filtered.columns].copy()

# %% [markdown]
# ### Create datasets

# %%
#### Drop ASVs which are not present in 508 samples

clusters = ["A", "B", "C", "D", "E", "F", "I", "H", "G"] 

cluster_asv_data = {}

# Loop through each unique cluster
for cluster in clusters:
    # Get the sample IDs that belong to the current cluster
    sample_ids = cluster_df.loc[cluster_df['cluster'] == cluster].index.astype(str)
    
    # Select the columns in asv_ige_508_all corresponding to these sample IDs
    cluster_asv = asv_ige_508_all.loc[:, asv_ige_508_all.columns.isin(sample_ids)]
    
    # Store the ASV data for the current cluster in the dictionary
    cluster_asv_data[cluster] = cluster_asv

    
healthy_asv = asv_ige_508_all[control_sample_df.index.astype(str)]
allergic_asv = asv_ige_508_all.loc[:, ~asv_ige_508_all.columns.isin(control_sample_df.index.astype(str))]

cluster_asv_data["healthy"] = healthy_asv
cluster_asv_data["allergic"] = allergic_asv
cluster_asv_data["all"] = asv_ige_508_all

# %%
levels = ["phylum", "class", "order", "family", "genus", "species", "ASV"]

# Define thresholds to iterate over
thresholds = [0.01, 0.05, 0.1, 0.2]

# Dictionary to store results for each threshold
results_by_threshold = {}

for threshold in thresholds:
    print(f"\n{'='*60}")
    print(f"PROCESSING THRESHOLD: {threshold}")
    print(f"{'='*60}")
    
    data_dict = dict()
    
    for cluster, asv_table in cluster_asv_data.items():
        print(f"\n=== Cluster: {cluster} ===")

        ASV_table = asv_table.copy()
        # Initialize dictionary for the current cluster
        if cluster not in data_dict:
            data_dict[cluster] = {}

        #################### DROP ZERO FEATURES ##############################
        print(f"ASVs BEFORE dropping zero features: p = {ASV_table.shape[0]}")

        ### Frequency of bacterium across all samples
        taxa_freq = ASV_table.sum(axis=1)

        ### drop features with NO COUNTS
        non_zero_taxa = taxa_freq[taxa_freq > 0]

        ### Filter ASV table based on non-zero frequencies
        ASV_table_non_zero = ASV_table[ASV_table.index.isin(non_zero_taxa.index)]

        ### Filter columns with zero mean
        asv_samples_ids = set(ASV_table_non_zero.columns)
        means = ASV_table_non_zero.mean()
        zero_mean_cols = means[means == 0].index

        ### Drop columns with zero mean if any
        if any(zero_mean_cols):
            print(f"Zero mean features found and removed: {list(zero_mean_cols)}")
            ASV_table_non_zero = ASV_table_non_zero.drop(zero_mean_cols, axis=1)

        print(f"ASVs AFTER dropping zero features: p = {ASV_table_non_zero.shape[0]}")

        for level in levels:
            print(f"\n--- Level: {level} ---")

            ##################### AGGREGATION ##############################
            counts_plus_label = ASV_table_non_zero.join(taxa[level])
            counts = counts_plus_label.groupby(level).sum()

            ### DO THE FILTERING ON EVERY LEVEL
            counts_freq = counts.astype(bool).sum(axis=1) / counts.shape[1]
            filter_threshold = counts_freq[counts_freq > threshold]
            counts_filtered = counts[counts.index.isin(filter_threshold.index)]

            ### Apply CLR transformation
            clr_counts = transform_features(counts_filtered, transformation='clr')
            mclr_counts = transform_features(counts_filtered, transformation='mclr')
            
            ### Calculate covariance
            S0 = np.cov(clr_counts.values, bias = True)
            S = scale_array_by_diagonal(S0)
            corr_df = pd.DataFrame(S, index=clr_counts.index, columns=clr_counts.index)

            data_dict[cluster][level] = {'raw_counts': counts_filtered, 
                                         'clr_counts': clr_counts, 
                                         'mclr_counts': mclr_counts,
                                         "corr": corr_df}

            print(f"{level} count table shape: p = {counts_filtered.shape[0]}, N = {counts_filtered.shape[1]}")
    
    # Store the data_dict for this threshold
    results_by_threshold[threshold] = data_dict
    
    # # Save to pickle file
    with open(f'data_dict_threshold_{threshold}.pkl', 'wb') as f:
        pkl.dump(data_dict, f)
    print(f"\nSaved data_dict for threshold {threshold} to 'data_dict_threshold_{threshold}.pkl'")
# Out:
# ============================================================
# PROCESSING THRESHOLD: 0.01
# ============================================================
#
# === Cluster: A ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 758
#
# --- Level: phylum ---
# phylum count table shape: p = 10, N = 12
#
# --- Level: class ---
# class count table shape: p = 15, N = 12
#
# --- Level: order ---
# order count table shape: p = 30, N = 12
#
# --- Level: family ---
# family count table shape: p = 62, N = 12
#
# --- Level: genus ---
# genus count table shape: p = 249, N = 12
#
# --- Level: species ---
# species count table shape: p = 710, N = 12
#
# --- Level: ASV ---
# ASV count table shape: p = 758, N = 12
#
# === Cluster: B ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1276
#
# --- Level: phylum ---
# phylum count table shape: p = 11, N = 24
#
# --- Level: class ---
# class count table shape: p = 17, N = 24
#
# --- Level: order ---
# order count table shape: p = 43, N = 24
#
# --- Level: family ---
# family count table shape: p = 89, N = 24
#
# --- Level: genus ---
# genus count table shape: p = 369, N = 24
#
# --- Level: species ---
# species count table shape: p = 1184, N = 24
#
# --- Level: ASV ---
# ASV count table shape: p = 1276, N = 24
#
# === Cluster: C ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1289
#
# --- Level: phylum ---
# phylum count table shape: p = 11, N = 26
#
# --- Level: class ---
# class count table shape: p = 17, N = 26
#
# --- Level: order ---
# order count table shape: p = 39, N = 26
#
# --- Level: family ---
# family count table shape: p = 77, N = 26
#
# --- Level: genus ---
# genus count table shape: p = 372, N = 26
#
# --- Level: species ---
# species count table shape: p = 1203, N = 26
#
# --- Level: ASV ---
# ASV count table shape: p = 1289, N = 26
#
# === Cluster: D ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1834
#
# --- Level: phylum ---
# phylum count table shape: p = 12, N = 45
#
# --- Level: class ---
# class count table shape: p = 19, N = 45
#
# --- Level: order ---
# order count table shape: p = 49, N = 45
#
# --- Level: family ---
# family count table shape: p = 100, N = 45
#
# --- Level: genus ---
# genus count table shape: p = 456, N = 45
#
# --- Level: species ---
# species count table shape: p = 1697, N = 45
#
# --- Level: ASV ---
# ASV count table shape: p = 1834, N = 45
#
# === Cluster: E ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1107
#
# --- Level: phylum ---
# phylum count table shape: p = 10, N = 22
#
# --- Level: class ---
# class count table shape: p = 16, N = 22
#
# --- Level: order ---
# order count table shape: p = 38, N = 22
#
# --- Level: family ---
# family count table shape: p = 75, N = 22
#
# --- Level: genus ---
# genus count table shape: p = 320, N = 22
#
# --- Level: species ---
# species count table shape: p = 1037, N = 22
#
# --- Level: ASV ---
# ASV count table shape: p = 1107, N = 22
#
# === Cluster: F ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 507
#
# --- Level: phylum ---
# phylum count table shape: p = 7, N = 10
#
# --- Level: class ---
# class count table shape: p = 12, N = 10
#
# --- Level: order ---
# order count table shape: p = 27, N = 10
#
# --- Level: family ---
# family count table shape: p = 52, N = 10
#
# --- Level: genus ---
# genus count table shape: p = 181, N = 10
#
# --- Level: species ---
# species count table shape: p = 482, N = 10
#
# --- Level: ASV ---
# ASV count table shape: p = 507, N = 10
#
# === Cluster: I ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 2420
#
# --- Level: phylum ---
# phylum count table shape: p = 11, N = 74
#
# --- Level: class ---
# class count table shape: p = 18, N = 74
#
# --- Level: order ---
# order count table shape: p = 52, N = 74
#
# --- Level: family ---
# family count table shape: p = 110, N = 74
#
# --- Level: genus ---
# genus count table shape: p = 580, N = 74
#
# --- Level: species ---
# species count table shape: p = 2226, N = 74
#
# --- Level: ASV ---
# ASV count table shape: p = 2420, N = 74
#
# === Cluster: H ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1709
#
# --- Level: phylum ---
# phylum count table shape: p = 12, N = 40
#
# --- Level: class ---
# class count table shape: p = 17, N = 40
#
# --- Level: order ---
# order count table shape: p = 48, N = 40
#
# --- Level: family ---
# family count table shape: p = 91, N = 40
#
# --- Level: genus ---
# genus count table shape: p = 452, N = 40
#
# --- Level: species ---
# species count table shape: p = 1587, N = 40
#
# --- Level: ASV ---
# ASV count table shape: p = 1709, N = 40
#
# === Cluster: G ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1162
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 22
#
# --- Level: class ---
# class count table shape: p = 14, N = 22
#
# --- Level: order ---
# order count table shape: p = 35, N = 22
#
# --- Level: family ---
# family count table shape: p = 72, N = 22
#
# --- Level: genus ---
# genus count table shape: p = 309, N = 22
#
# --- Level: species ---
# species count table shape: p = 1077, N = 22
#
# --- Level: ASV ---
# ASV count table shape: p = 1162, N = 22
#
# === Cluster: healthy ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 4678
#
# --- Level: phylum ---
# phylum count table shape: p = 12, N = 233
#
# --- Level: class ---
# class count table shape: p = 19, N = 233
#
# --- Level: order ---
# order count table shape: p = 48, N = 233
#
# --- Level: family ---
# family count table shape: p = 91, N = 233
#
# --- Level: genus ---
# genus count table shape: p = 437, N = 233
#
# --- Level: species ---
# species count table shape: p = 1440, N = 233
#
# --- Level: ASV ---
# ASV count table shape: p = 1538, N = 233
#
# === Cluster: allergic ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 4929
#
# --- Level: phylum ---
# phylum count table shape: p = 12, N = 275
#
# --- Level: class ---
# class count table shape: p = 18, N = 275
#
# --- Level: order ---
# order count table shape: p = 47, N = 275
#
# --- Level: family ---
# family count table shape: p = 93, N = 275
#
# --- Level: genus ---
# genus count table shape: p = 431, N = 275
#
# --- Level: species ---
# species count table shape: p = 1492, N = 275
#
# --- Level: ASV ---
# ASV count table shape: p = 1592, N = 275
#
# === Cluster: all ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 6958
#
# --- Level: phylum ---
# phylum count table shape: p = 12, N = 508
#
# --- Level: class ---
# class count table shape: p = 18, N = 508
#
# --- Level: order ---
# order count table shape: p = 47, N = 508
#
# --- Level: family ---
# family count table shape: p = 91, N = 508
#
# --- Level: genus ---
# genus count table shape: p = 402, N = 508
#
# --- Level: species ---
# species count table shape: p = 1329, N = 508
#
# --- Level: ASV ---
# ASV count table shape: p = 1422, N = 508
#
# Saved data_dict for threshold 0.01 to 'data_dict_threshold_0.01.pkl'
#
# ============================================================
# PROCESSING THRESHOLD: 0.05
# ============================================================
#
# === Cluster: A ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 758
#
# --- Level: phylum ---
# phylum count table shape: p = 10, N = 12
#
# --- Level: class ---
# class count table shape: p = 15, N = 12
#
# --- Level: order ---
# order count table shape: p = 30, N = 12
#
# --- Level: family ---
# family count table shape: p = 62, N = 12
#
# --- Level: genus ---
# genus count table shape: p = 249, N = 12
#
# --- Level: species ---
# species count table shape: p = 710, N = 12
#
# --- Level: ASV ---
# ASV count table shape: p = 758, N = 12
#
# === Cluster: B ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1276
#
# --- Level: phylum ---
# phylum count table shape: p = 9, N = 24
#
# --- Level: class ---
# class count table shape: p = 14, N = 24
#
# --- Level: order ---
# order count table shape: p = 30, N = 24
#
# --- Level: family ---
# family count table shape: p = 58, N = 24
#
# --- Level: genus ---
# genus count table shape: p = 197, N = 24
#
# --- Level: species ---
# species count table shape: p = 473, N = 24
#
# --- Level: ASV ---
# ASV count table shape: p = 483, N = 24
#
# === Cluster: C ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1289
#
# --- Level: phylum ---
# phylum count table shape: p = 10, N = 26
#
# --- Level: class ---
# class count table shape: p = 16, N = 26
#
# --- Level: order ---
# order count table shape: p = 33, N = 26
#
# --- Level: family ---
# family count table shape: p = 61, N = 26
#
# --- Level: genus ---
# genus count table shape: p = 200, N = 26
#
# --- Level: species ---
# species count table shape: p = 470, N = 26
#
# --- Level: ASV ---
# ASV count table shape: p = 487, N = 26
#
# === Cluster: D ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1834
#
# --- Level: phylum ---
# phylum count table shape: p = 9, N = 45
#
# --- Level: class ---
# class count table shape: p = 15, N = 45
#
# --- Level: order ---
# order count table shape: p = 35, N = 45
#
# --- Level: family ---
# family count table shape: p = 62, N = 45
#
# --- Level: genus ---
# genus count table shape: p = 197, N = 45
#
# --- Level: species ---
# species count table shape: p = 464, N = 45
#
# --- Level: ASV ---
# ASV count table shape: p = 477, N = 45
#
# === Cluster: E ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1107
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 22
#
# --- Level: class ---
# class count table shape: p = 13, N = 22
#
# --- Level: order ---
# order count table shape: p = 31, N = 22
#
# --- Level: family ---
# family count table shape: p = 56, N = 22
#
# --- Level: genus ---
# genus count table shape: p = 180, N = 22
#
# --- Level: species ---
# species count table shape: p = 402, N = 22
#
# --- Level: ASV ---
# ASV count table shape: p = 419, N = 22
#
# === Cluster: F ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 507
#
# --- Level: phylum ---
# phylum count table shape: p = 7, N = 10
#
# --- Level: class ---
# class count table shape: p = 12, N = 10
#
# --- Level: order ---
# order count table shape: p = 27, N = 10
#
# --- Level: family ---
# family count table shape: p = 52, N = 10
#
# --- Level: genus ---
# genus count table shape: p = 181, N = 10
#
# --- Level: species ---
# species count table shape: p = 482, N = 10
#
# --- Level: ASV ---
# ASV count table shape: p = 507, N = 10
#
# === Cluster: I ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 2420
#
# --- Level: phylum ---
# phylum count table shape: p = 9, N = 74
#
# --- Level: class ---
# class count table shape: p = 15, N = 74
#
# --- Level: order ---
# order count table shape: p = 33, N = 74
#
# --- Level: family ---
# family count table shape: p = 63, N = 74
#
# --- Level: genus ---
# genus count table shape: p = 208, N = 74
#
# --- Level: species ---
# species count table shape: p = 528, N = 74
#
# --- Level: ASV ---
# ASV count table shape: p = 546, N = 74
#
# === Cluster: H ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1709
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 40
#
# --- Level: class ---
# class count table shape: p = 13, N = 40
#
# --- Level: order ---
# order count table shape: p = 30, N = 40
#
# --- Level: family ---
# family count table shape: p = 58, N = 40
#
# --- Level: genus ---
# genus count table shape: p = 191, N = 40
#
# --- Level: species ---
# species count table shape: p = 440, N = 40
#
# --- Level: ASV ---
# ASV count table shape: p = 453, N = 40
#
# === Cluster: G ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1162
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 22
#
# --- Level: class ---
# class count table shape: p = 13, N = 22
#
# --- Level: order ---
# order count table shape: p = 31, N = 22
#
# --- Level: family ---
# family count table shape: p = 60, N = 22
#
# --- Level: genus ---
# genus count table shape: p = 191, N = 22
#
# --- Level: species ---
# species count table shape: p = 433, N = 22
#
# --- Level: ASV ---
# ASV count table shape: p = 442, N = 22
#
# === Cluster: healthy ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 4678
#
# --- Level: phylum ---
# phylum count table shape: p = 9, N = 233
#
# --- Level: class ---
# class count table shape: p = 15, N = 233
#
# --- Level: order ---
# order count table shape: p = 33, N = 233
#
# --- Level: family ---
# family count table shape: p = 61, N = 233
#
# --- Level: genus ---
# genus count table shape: p = 215, N = 233
#
# --- Level: species ---
# species count table shape: p = 490, N = 233
#
# --- Level: ASV ---
# ASV count table shape: p = 501, N = 233
#
# === Cluster: allergic ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 4929
#
# --- Level: phylum ---
# phylum count table shape: p = 9, N = 275
#
# --- Level: class ---
# class count table shape: p = 15, N = 275
#
# --- Level: order ---
# order count table shape: p = 34, N = 275
#
# --- Level: family ---
# family count table shape: p = 63, N = 275
#
# --- Level: genus ---
# genus count table shape: p = 203, N = 275
#
# --- Level: species ---
# species count table shape: p = 466, N = 275
#
# --- Level: ASV ---
# ASV count table shape: p = 482, N = 275
#
# === Cluster: all ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 6958
#
# --- Level: phylum ---
# phylum count table shape: p = 9, N = 508
#
# --- Level: class ---
# class count table shape: p = 15, N = 508
#
# --- Level: order ---
# order count table shape: p = 34, N = 508
#
# --- Level: family ---
# family count table shape: p = 63, N = 508
#
# --- Level: genus ---
# genus count table shape: p = 211, N = 508
#
# --- Level: species ---
# species count table shape: p = 476, N = 508
#
# --- Level: ASV ---
# ASV count table shape: p = 486, N = 508
#
# Saved data_dict for threshold 0.05 to 'data_dict_threshold_0.05.pkl'
#
# ============================================================
# PROCESSING THRESHOLD: 0.1
# ============================================================
#
# === Cluster: A ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 758
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 12
#
# --- Level: class ---
# class count table shape: p = 12, N = 12
#
# --- Level: order ---
# order count table shape: p = 25, N = 12
#
# --- Level: family ---
# family count table shape: p = 44, N = 12
#
# --- Level: genus ---
# genus count table shape: p = 134, N = 12
#
# --- Level: species ---
# species count table shape: p = 293, N = 12
#
# --- Level: ASV ---
# ASV count table shape: p = 301, N = 12
#
# === Cluster: B ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1276
#
# --- Level: phylum ---
# phylum count table shape: p = 9, N = 24
#
# --- Level: class ---
# class count table shape: p = 14, N = 24
#
# --- Level: order ---
# order count table shape: p = 30, N = 24
#
# --- Level: family ---
# family count table shape: p = 52, N = 24
#
# --- Level: genus ---
# genus count table shape: p = 154, N = 24
#
# --- Level: species ---
# species count table shape: p = 323, N = 24
#
# --- Level: ASV ---
# ASV count table shape: p = 323, N = 24
#
# === Cluster: C ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1289
#
# --- Level: phylum ---
# phylum count table shape: p = 10, N = 26
#
# --- Level: class ---
# class count table shape: p = 15, N = 26
#
# --- Level: order ---
# order count table shape: p = 32, N = 26
#
# --- Level: family ---
# family count table shape: p = 53, N = 26
#
# --- Level: genus ---
# genus count table shape: p = 153, N = 26
#
# --- Level: species ---
# species count table shape: p = 315, N = 26
#
# --- Level: ASV ---
# ASV count table shape: p = 319, N = 26
#
# === Cluster: D ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1834
#
# --- Level: phylum ---
# phylum count table shape: p = 9, N = 45
#
# --- Level: class ---
# class count table shape: p = 15, N = 45
#
# --- Level: order ---
# order count table shape: p = 31, N = 45
#
# --- Level: family ---
# family count table shape: p = 56, N = 45
#
# --- Level: genus ---
# genus count table shape: p = 154, N = 45
#
# --- Level: species ---
# species count table shape: p = 297, N = 45
#
# --- Level: ASV ---
# ASV count table shape: p = 301, N = 45
#
# === Cluster: E ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1107
#
# --- Level: phylum ---
# phylum count table shape: p = 7, N = 22
#
# --- Level: class ---
# class count table shape: p = 12, N = 22
#
# --- Level: order ---
# order count table shape: p = 25, N = 22
#
# --- Level: family ---
# family count table shape: p = 48, N = 22
#
# --- Level: genus ---
# genus count table shape: p = 134, N = 22
#
# --- Level: species ---
# species count table shape: p = 267, N = 22
#
# --- Level: ASV ---
# ASV count table shape: p = 272, N = 22
#
# === Cluster: F ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 507
#
# --- Level: phylum ---
# phylum count table shape: p = 7, N = 10
#
# --- Level: class ---
# class count table shape: p = 11, N = 10
#
# --- Level: order ---
# order count table shape: p = 24, N = 10
#
# --- Level: family ---
# family count table shape: p = 42, N = 10
#
# --- Level: genus ---
# genus count table shape: p = 112, N = 10
#
# --- Level: species ---
# species count table shape: p = 205, N = 10
#
# --- Level: ASV ---
# ASV count table shape: p = 209, N = 10
#
# === Cluster: I ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 2420
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 74
#
# --- Level: class ---
# class count table shape: p = 13, N = 74
#
# --- Level: order ---
# order count table shape: p = 28, N = 74
#
# --- Level: family ---
# family count table shape: p = 50, N = 74
#
# --- Level: genus ---
# genus count table shape: p = 148, N = 74
#
# --- Level: species ---
# species count table shape: p = 297, N = 74
#
# --- Level: ASV ---
# ASV count table shape: p = 299, N = 74
#
# === Cluster: H ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1709
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 40
#
# --- Level: class ---
# class count table shape: p = 13, N = 40
#
# --- Level: order ---
# order count table shape: p = 27, N = 40
#
# --- Level: family ---
# family count table shape: p = 49, N = 40
#
# --- Level: genus ---
# genus count table shape: p = 145, N = 40
#
# --- Level: species ---
# species count table shape: p = 285, N = 40
#
# --- Level: ASV ---
# ASV count table shape: p = 292, N = 40
#
# === Cluster: G ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1162
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 22
#
# --- Level: class ---
# class count table shape: p = 13, N = 22
#
# --- Level: order ---
# order count table shape: p = 29, N = 22
#
# --- Level: family ---
# family count table shape: p = 50, N = 22
#
# --- Level: genus ---
# genus count table shape: p = 144, N = 22
#
# --- Level: species ---
# species count table shape: p = 286, N = 22
#
# --- Level: ASV ---
# ASV count table shape: p = 283, N = 22
#
# === Cluster: healthy ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 4678
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 233
#
# --- Level: class ---
# class count table shape: p = 13, N = 233
#
# --- Level: order ---
# order count table shape: p = 27, N = 233
#
# --- Level: family ---
# family count table shape: p = 49, N = 233
#
# --- Level: genus ---
# genus count table shape: p = 156, N = 233
#
# --- Level: species ---
# species count table shape: p = 292, N = 233
#
# --- Level: ASV ---
# ASV count table shape: p = 294, N = 233
#
# === Cluster: allergic ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 4929
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 275
#
# --- Level: class ---
# class count table shape: p = 13, N = 275
#
# --- Level: order ---
# order count table shape: p = 28, N = 275
#
# --- Level: family ---
# family count table shape: p = 50, N = 275
#
# --- Level: genus ---
# genus count table shape: p = 146, N = 275
#
# --- Level: species ---
# species count table shape: p = 293, N = 275
#
# --- Level: ASV ---
# ASV count table shape: p = 297, N = 275
#
# === Cluster: all ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 6958
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 508
#
# --- Level: class ---
# class count table shape: p = 13, N = 508
#
# --- Level: order ---
# order count table shape: p = 28, N = 508
#
# --- Level: family ---
# family count table shape: p = 49, N = 508
#
# --- Level: genus ---
# genus count table shape: p = 149, N = 508
#
# --- Level: species ---
# species count table shape: p = 289, N = 508
#
# --- Level: ASV ---
# ASV count table shape: p = 296, N = 508
#
# Saved data_dict for threshold 0.1 to 'data_dict_threshold_0.1.pkl'
#
# ============================================================
# PROCESSING THRESHOLD: 0.2
# ============================================================
#
# === Cluster: A ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 758
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 12
#
# --- Level: class ---
# class count table shape: p = 12, N = 12
#
# --- Level: order ---
# order count table shape: p = 22, N = 12
#
# --- Level: family ---
# family count table shape: p = 39, N = 12
#
# --- Level: genus ---
# genus count table shape: p = 109, N = 12
#
# --- Level: species ---
# species count table shape: p = 199, N = 12
#
# --- Level: ASV ---
# ASV count table shape: p = 199, N = 12
#
# === Cluster: B ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1276
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 24
#
# --- Level: class ---
# class count table shape: p = 13, N = 24
#
# --- Level: order ---
# order count table shape: p = 26, N = 24
#
# --- Level: family ---
# family count table shape: p = 43, N = 24
#
# --- Level: genus ---
# genus count table shape: p = 113, N = 24
#
# --- Level: species ---
# species count table shape: p = 182, N = 24
#
# --- Level: ASV ---
# ASV count table shape: p = 178, N = 24
#
# === Cluster: C ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1289
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 26
#
# --- Level: class ---
# class count table shape: p = 13, N = 26
#
# --- Level: order ---
# order count table shape: p = 27, N = 26
#
# --- Level: family ---
# family count table shape: p = 43, N = 26
#
# --- Level: genus ---
# genus count table shape: p = 110, N = 26
#
# --- Level: species ---
# species count table shape: p = 163, N = 26
#
# --- Level: ASV ---
# ASV count table shape: p = 162, N = 26
#
# === Cluster: D ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1834
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 45
#
# --- Level: class ---
# class count table shape: p = 13, N = 45
#
# --- Level: order ---
# order count table shape: p = 26, N = 45
#
# --- Level: family ---
# family count table shape: p = 41, N = 45
#
# --- Level: genus ---
# genus count table shape: p = 104, N = 45
#
# --- Level: species ---
# species count table shape: p = 174, N = 45
#
# --- Level: ASV ---
# ASV count table shape: p = 176, N = 45
#
# === Cluster: E ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1107
#
# --- Level: phylum ---
# phylum count table shape: p = 7, N = 22
#
# --- Level: class ---
# class count table shape: p = 11, N = 22
#
# --- Level: order ---
# order count table shape: p = 21, N = 22
#
# --- Level: family ---
# family count table shape: p = 38, N = 22
#
# --- Level: genus ---
# genus count table shape: p = 105, N = 22
#
# --- Level: species ---
# species count table shape: p = 167, N = 22
#
# --- Level: ASV ---
# ASV count table shape: p = 162, N = 22
#
# === Cluster: F ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 507
#
# --- Level: phylum ---
# phylum count table shape: p = 7, N = 10
#
# --- Level: class ---
# class count table shape: p = 11, N = 10
#
# --- Level: order ---
# order count table shape: p = 22, N = 10
#
# --- Level: family ---
# family count table shape: p = 35, N = 10
#
# --- Level: genus ---
# genus count table shape: p = 83, N = 10
#
# --- Level: species ---
# species count table shape: p = 130, N = 10
#
# --- Level: ASV ---
# ASV count table shape: p = 125, N = 10
#
# === Cluster: I ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 2420
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 74
#
# --- Level: class ---
# class count table shape: p = 13, N = 74
#
# --- Level: order ---
# order count table shape: p = 26, N = 74
#
# --- Level: family ---
# family count table shape: p = 43, N = 74
#
# --- Level: genus ---
# genus count table shape: p = 108, N = 74
#
# --- Level: species ---
# species count table shape: p = 176, N = 74
#
# --- Level: ASV ---
# ASV count table shape: p = 171, N = 74
#
# === Cluster: H ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1709
#
# --- Level: phylum ---
# phylum count table shape: p = 7, N = 40
#
# --- Level: class ---
# class count table shape: p = 12, N = 40
#
# --- Level: order ---
# order count table shape: p = 25, N = 40
#
# --- Level: family ---
# family count table shape: p = 42, N = 40
#
# --- Level: genus ---
# genus count table shape: p = 108, N = 40
#
# --- Level: species ---
# species count table shape: p = 165, N = 40
#
# --- Level: ASV ---
# ASV count table shape: p = 160, N = 40
#
# === Cluster: G ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 1162
#
# --- Level: phylum ---
# phylum count table shape: p = 7, N = 22
#
# --- Level: class ---
# class count table shape: p = 12, N = 22
#
# --- Level: order ---
# order count table shape: p = 25, N = 22
#
# --- Level: family ---
# family count table shape: p = 41, N = 22
#
# --- Level: genus ---
# genus count table shape: p = 108, N = 22
#
# --- Level: species ---
# species count table shape: p = 168, N = 22
#
# --- Level: ASV ---
# ASV count table shape: p = 160, N = 22
#
# === Cluster: healthy ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 4678
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 233
#
# --- Level: class ---
# class count table shape: p = 13, N = 233
#
# --- Level: order ---
# order count table shape: p = 26, N = 233
#
# --- Level: family ---
# family count table shape: p = 42, N = 233
#
# --- Level: genus ---
# genus count table shape: p = 108, N = 233
#
# --- Level: species ---
# species count table shape: p = 165, N = 233
#
# --- Level: ASV ---
# ASV count table shape: p = 159, N = 233
#
# === Cluster: allergic ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 4929
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 275
#
# --- Level: class ---
# class count table shape: p = 13, N = 275
#
# --- Level: order ---
# order count table shape: p = 26, N = 275
#
# --- Level: family ---
# family count table shape: p = 41, N = 275
#
# --- Level: genus ---
# genus count table shape: p = 106, N = 275
#
# --- Level: species ---
# species count table shape: p = 165, N = 275
#
# --- Level: ASV ---
# ASV count table shape: p = 162, N = 275
#
# === Cluster: all ===
# ASVs BEFORE dropping zero features: p = 15170
# ASVs AFTER dropping zero features: p = 6958
#
# --- Level: phylum ---
# phylum count table shape: p = 8, N = 508
#
# --- Level: class ---
# class count table shape: p = 13, N = 508
#
# --- Level: order ---
# order count table shape: p = 26, N = 508
#
# --- Level: family ---
# family count table shape: p = 41, N = 508
#
# --- Level: genus ---
# genus count table shape: p = 106, N = 508
#
# --- Level: species ---
# species count table shape: p = 160, N = 508
#
# --- Level: ASV ---
# ASV count table shape: p = 156, N = 508
#
# Saved data_dict for threshold 0.2 to 'data_dict_threshold_0.2.pkl'

# %%
# with open('data/cluster_count_dict.pkl', 'wb') as f:
#     pkl.dump(data_dict, f)

threshold = 0.2
    
with open(f'data_dict_threshold_{threshold}.pkl', 'rb') as f:
    data_dict = pkl.load(f)

# %%
level = 'family'

# Extract the counts
counts_healthy = data_dict["healthy"][level]["raw_counts"]
counts_allergic = data_dict["allergic"][level]["raw_counts"]
counts_A = data_dict["A"][level]["raw_counts"]
counts_E = data_dict["E"][level]["raw_counts"]
counts_D = data_dict["D"][level]["raw_counts"]
counts_B = data_dict["B"][level]["raw_counts"]

# Save as CSV files
counts_healthy.to_csv(f'data/counts_healthy_{level}.csv')
counts_allergic.to_csv(f'data/counts_allergic_{level}.csv')
counts_A.to_csv(f'data/counts_A_{level}.csv')
counts_E.to_csv(f'data/counts_E_{level}.csv')
counts_D.to_csv(f'data/counts_D_{level}.csv')
counts_B.to_csv(f'data/counts_B_{level}.csv')

print("✓ Saved:")
print(f"  - data/counts_healthy_{level}.csv")
print(f"  - data/counts_allergic_{level}.csv")
print(f"  - data/counts_A_{level}.csv")
print(f"  - data/counts_E_{level}.csv")
print(f"  - data/counts_D_{level}.csv")
print(f"  - data/counts_B_{level}.csv")
# Out:
# ✓ Saved:
#   - data/counts_healthy_family.csv
#   - data/counts_allergic_family.csv
#   - data/counts_A_family.csv
#   - data/counts_E_family.csv
#   - data/counts_D_family.csv
#   - data/counts_B_family.csv

# %% [markdown]
# #### We use R package NetCoMi for the visualization (code is available in RMarkdown)
